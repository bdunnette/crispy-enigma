# %%
# Install GeoPandas and Folium requirements
# %pip install -q geopandas folium
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import libraries
import folium
import folium.plugins as plugins
import geopandas as gpd
import pandas as pd

# %%
# If running in jupyterlite, import pyodide_http to patch urllib for loading data from URLs
import sys

if "pyodide" in sys.modules:
    print("Running in Pyodide environment - patching HTTP requests with pyodide_http")
    import pyodide_http

    pyodide_http.patch_all()
else:
    print("Running in standard Python environment - no need to patch urllib")
    pass
# Out:
# Running in standard Python environment

# %%
# Load and display a sample GeoDataFrame
minneapolis_zoning = gpd.read_file(
    "https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Planning_Primary_Zoning/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson"
)
minneapolis_zoning
# Out:
#       OBJECTID                      Land_Use Land_Use_Code  RuleID  \
# 0            1  Residence Goods and Services           RM1     9.0
# 1            2        Neighborhood Mixed Use           CM1     1.0
# 2            3        Neighborhood Mixed Use           CM1     1.0
# 3            4          Urban Neighborhood 2           UN2    14.0
# 4            5          Urban Neighborhood 3           UN3    15.0
# ...        ...                           ...           ...     ...
# 1254      1255  Residence Goods and Services           RM1     NaN
# 1255      1256        Neighborhood Mixed Use           CM1     1.0
# 1256      1257          Urban Neighborhood 3           UN3    15.0
# 1257      1258           Community Mixed Use           CM3     3.0
# 1258      1259  Residence Goods and Services           RM1     9.0
#
#         Shape__Area  Shape__Length  \
# 0      15994.910156     764.878945
# 1     200440.085938    3108.958708
# 2       7054.164062     383.059472
# 3     101409.589844    1883.919060
# 4     236796.332031    3729.634584
# ...             ...            ...
# 1254   75522.187634    1446.514524
# 1255    1813.054688     171.985610
# 1256     771.996094     114.804754
# 1257   25280.101562     663.575011
# 1258  149746.617188    3276.974600
#
#                                                geometry
# 0     POLYGON ((-93.23025 44.98469, -93.22915 44.984...
# 1     POLYGON ((-93.29769 44.94659, -93.29766 44.946...
# 2     POLYGON ((-93.2696 44.95952, -93.26885 44.9595...
# 3     POLYGON ((-93.21831 44.98744, -93.21794 44.987...
# 4     POLYGON ((-93.31164 44.9339, -93.31152 44.9339...
# ...                                                 ...
# 1254  POLYGON ((-93.30757 45.00213, -93.30757 45.000...
# 1255  POLYGON ((-93.22028 44.94172, -93.22006 44.941...
# 1256  POLYGON ((-93.29116 44.9412, -93.29117 44.9410...
# 1257  POLYGON ((-93.26204 44.94766, -93.26201 44.947...
# 1258  POLYGON ((-93.2631 45.00649, -93.2631 45.00639...
#
# [1259 rows x 7 columns]

# %%
# Render a simple map centered on Minneapolis containing the geometries
m = folium.Map(location=[44.9778, -93.2650], zoom_start=12)
popup = folium.GeoJsonPopup(fields=["Land_Use", "Land_Use_Code"])
mpls_zoning = folium.GeoJson(
    minneapolis_zoning,
    # Color residential zones green and commercial zones orange
    style_function=lambda feature: {
        "fillColor": "green"
        if feature["properties"]["Land_Use_Code"].startswith("U")
        else "orange",
        "color": "black",
        "weight": 0.5,
        "fillOpacity": 0.5,
    },
    popup=popup,
    popup_keep_highlighted=True,
    tooltip=folium.GeoJsonTooltip(fields=["Land_Use", "Land_Use_Code"]),
).add_to(m)
# Add fullscreen button
plugins.Fullscreen().add_to(m)
# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34430a02cc7b6fe129d83fe7f6f88403 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34430a02cc7b6fe129d83fe7f6f88403&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34430a02cc7b6fe129d83fe7f6f88403 = L.map(
#                 &quot;map_34430a02cc7b6fe129d83fe7f6f88403&quot;,
#                 {
#                     center: [44.9778, -93.265],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_494e6485847b5fab52ff5868d96c5b5b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_494e6485847b5fab52ff5868d96c5b5b.addTo(map_34430a02cc7b6fe129d83fe7f6f88403);
#
#
#         function geo_json_5eda12b21b4ec259def505cd3f44fff8_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;8&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;20&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;44&quot;: case &quot;46&quot;: case &quot;48&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;65&quot;: case &quot;66&quot;: case &quot;68&quot;: case &quot;70&quot;: case &quot;72&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;85&quot;: case &quot;87&quot;: case &quot;88&quot;: case &quot;90&quot;: case &quot;92&quot;: case &quot;94&quot;: case &quot;95&quot;: case &quot;99&quot;: case &quot;101&quot;: case &quot;102&quot;: case &quot;103&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;110&quot;: case &quot;111&quot;: case &quot;112&quot;: case &quot;115&quot;: case &quot;117&quot;: case &quot;119&quot;: case &quot;121&quot;: case &quot;123&quot;: case &quot;124&quot;: case &quot;125&quot;: case &quot;126&quot;: case &quot;127&quot;: case &quot;129&quot;: case &quot;131&quot;: case &quot;134&quot;: case &quot;138&quot;: case &quot;139&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;146&quot;: case &quot;147&quot;: case &quot;148&quot;: case &quot;149&quot;: case &quot;151&quot;: case &quot;152&quot;: case &quot;153&quot;: case &quot;154&quot;: case &quot;155&quot;: case &quot;156&quot;: case &quot;158&quot;: case &quot;159&quot;: case &quot;162&quot;: case &quot;163&quot;: case &quot;165&quot;: case &quot;167&quot;: case &quot;173&quot;: case &quot;175&quot;: case &quot;176&quot;: case &quot;178&quot;: case &quot;181&quot;: case &quot;183&quot;: case &quot;186&quot;: case &quot;189&quot;: case &quot;193&quot;: case &quot;196&quot;: case &quot;198&quot;: case &quot;199&quot;: case &quot;201&quot;: case &quot;202&quot;
